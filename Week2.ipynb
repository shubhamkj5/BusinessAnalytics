# %% [markdown]
# # Python basics

# %%
#Cleaning Data
#Duplicate Values
#Handle missing values

# 11,12,11,11,10,9
# 1) removing missing value
# 3) average
# 4) median
# 5) using previous/next value

# %%
import pandas as pd

# %%
data=pd.read_csv("netflix_titles.csv")

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 2         s2  TV Show          Blood & Water              NaN
# 3         s3  TV Show              Ganglands  Julien Leclercq
# 4         s4  TV Show  Jailbirds New Orleans              NaN
# ...      ...      ...                    ...              ...
# 8803   s8803    Movie                 Zodiac    David Fincher
# 8804   s8804  TV Show            Zombie Dumb              NaN
# 8805   s8805    Movie             Zombieland  Ruben Fleischer
# 8806   s8806    Movie                   Zoom     Peter Hewitt
# 8807   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1                                                   NaN  United States
# ...

# %%
data_cleaned=data.drop_duplicates(subset=["type","cast","director"])
data_cleaned.shape
# Out:
# (8277, 12)

# %%
data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8277 entries, 0 to 8807
# Data columns (total 12 columns):
# show_id         8277 non-null object
# type            8277 non-null object
# title           8277 non-null object
# director        6046 non-null object
# cast            7836 non-null object
# country         7594 non-null object
# date_added      8267 non-null datetime64[ns]
# release_year    8277 non-null int64
# rating          8273 non-null object
# duration        8276 non-null object
# listed_in       8277 non-null object
# description     8277 non-null object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 840.6+ KB

# %%
data_cleaned['date_added'] = pd.to_datetime(data_cleaned['date_added'])
# Out:
# C:\Users\Shubham Jain\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
